# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\User\Downloads\DS-ASSIGNMENTS\Basic stats - 1\sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.shape
# Out:
# (450, 13)

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
numerical_columns = df.select_dtypes(include=['number']).columns.tolist()
print("Numerical columns:", numerical_columns)
# Out:
# Numerical columns: ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']

# %%
numeric_data=pd.DataFrame(numerical_columns)
numeric_data
# Out:
#                    0
# 0             Volume
# 1          Avg Price
# 2  Total Sales Value
# 3  Discount Rate (%)
# 4    Discount Amount
# 5    Net Sales Value

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
import matplotlib.pyplot as plt

columns=["Volume","Avg Price","Total Sales Value","Discount Rate (%)","Discount Amount","Net Sales Value"]

plt.figure(figsize=(12, 10))

for index, column in enumerate(columns, 1):
    plt.subplot(3, 2, index)  
    plt.hist(df[column], bins=10, alpha=0.7, color='blue')
    plt.title(column)
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()  
plt.show()

# %%
import matplotlib.pyplot as plt
columns=["Volume","Avg Price","Total Sales Value","Discount Rate (%)","Discount Amount","Net Sales Value"]
values=df.loc[:,["Volume","Avg Price","Total Sales Value","Discount Rate (%)","Discount Amount","Net Sales Value"]]
plt.figure(figsize=(11,9))
plt.boxplot(values,labels=columns)
plt.show()

# %%
categorical_columns = df.select_dtypes(include=['object', 'category']).columns
print("Categorical Columns:", categorical_columns)
# Out:
# Categorical Columns: Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
import matplotlib.pyplot as plt
for i in categorical_columns:
  print(i)
  # dataset[vis].value_counts().plot(kind='bar', color='skyblue')
  plt.barh(df[i],width=3)
  plt.title(f"bar chart of:{vis}")
  plt.show()
# Out:
# Date
# Day
# SKU
# City
# BU
# Brand
# Model

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler_data=scaler.fit_transform(df[columns])
print(scaler_data)
data_frame=pd.DataFrame(scaler_data,columns=columns)
print(data_frame)
# Out:
# [[ 2.35002911  0.091173    2.92572115 -0.83028851  3.95281631  2.80475594]
#  [ 1.16712855 -0.01957016  1.33099521 -0.85266145  1.84901409  1.2710262 ]
#  [ 0.45738822  0.31265934  1.56277525 -1.35163138  1.62299458  1.54567497]
#  ...
#  [-0.72551234 -0.49022863 -0.60644824  0.90379261 -0.60813967 -0.60192115]
#  [-0.48893223 -0.47361715 -0.55692259  0.38847428 -0.53037877 -0.55549857]
#  [-0.96209245 -0.40717125 -0.60842926  0.04223476 -0.63734468 -0.60123949]]
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.350029   0.091173           2.925721          -0.830289
# 1    1.167129  -0.019570           1.330995          -0.852661
# 2    0.457388   0.312659           1.562775          -1.351631
# 3    0.220808   0.534146           1.719276          -1.949723
# 4   -0.488932  -0.130313          -0.188452           0.673739
# ..        ...        ...                ...                ...
# 445 -0.725512  -0.506840          -0.618334           0.076009
# ...

# %%
import pandas as pd
onehot_coding=pd.get_dummies(df,columns=columns,drop_first=True)
onehot_coding.head()
# Out:
#          Date       Day  SKU City       BU  Brand       Model  Volume_2  \
# 0  01-04-2021  Thursday  M01    C  Mobiles  RealU       RU-10     False
# 1  01-04-2021  Thursday  M02    C  Mobiles  RealU   RU-9 Plus     False
# 2  01-04-2021  Thursday  M03    C  Mobiles   YouM       YM-99     False
# 3  01-04-2021  Thursday  M04    C  Mobiles   YouM  YM-99 Plus     False
# 4  01-04-2021  Thursday  M05    C  Mobiles   YouM      YM-98      False
#
#    Volume_3  Volume_4  ...  Net Sales Value_155761.9778062413  \
# 0     False     False  ...                              False
# 1     False     False  ...                              False
# 2     False     False  ...                              False
# 3     False     False  ...                              False
# 4      True     False  ...                              False
#
#    Net Sales Value_156330.96988962853  Net Sales Value_156895.96877157467  \
# 0                               False                               False
# ...
